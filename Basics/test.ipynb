# %%
print("Ain't shit funny!")
# Out:
# Ain't shit funny!

# %%
import pandas as pd

# %%
from datasets import load_dataset
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.
