# %%
import random

# %%
salary_list = [random.randint(50000, 150000) for _ in range(1_000_000)]

# %%
salary_list
# Out:
# [101659,
#  146579,
#  109892,
#  130646,
#  83494,
#  125086,
#  138703,
#  86630,
#  137111,
#  73785,
#  135460,
#  108504,
#  145053,
#  64337,
#  124098,
#  115775,
#  63838,
#  105453,
#  136682,
#  51702,
#  125459,
#  95739,
#  88066,
#  136869,
#  61730,
#  60916,
#  53746,
#  114096,
#  98269,
#  72931,
#  115936,
#  64352,
#  91249,
#  133664,
#  61525,
#  118759,
#  62458,
#  128647,
#  123740,
#  133056,
#  134051,
#  144117,
#  70562,
#  93537,
#  64535,
#  133660,
#  80600,
#  142314,
#  63829,
#  118278,
#  71331,
#  137590,
#  78869,
#  65160,
#  146815,
#  91041,
#  55764,
#  100662,
#  128464,
#  77694,
#  99877,
#  66547,
#  132751,
#  146456,
#  59322,
#  122297,
#  128530,
#  114421,
#  120016,
#  65698,
#  123457,
#  131492,
#  140743,
#  68383,
#  118436,
#  73547,
#  69124,
#  144457,
#  119037,
#  99690,
#  56204,
#  105720,
#  136630,
#  98126,
#  51779,
#  68765,
#  122331,
#  138694,
#  123229,
#  88504,
#  53103,
#  143741,
#  74532,
#  138727,
# ...

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 330 ms ± 77.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit

np.mean(salary_list)
# Out:
# 93.5 ms ± 44.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
my_array = np.array([1, 2, 3, 4])

# %%
float(my_array.mean())
# Out:
# 2.5

# %%
job_titles = np.array(['Data Engineer', 'Data Analyst', 'Financial Analyst', 'Data Scientist', 'AI Engineer'])

base_salaries = np.array([40000, 35000, 58000, 39000, np.nan])

bonus_rates = np.array([.1, .25, .12, .5, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([44000., 43750., 64960., 58500.,    nan])

# %%
np.nanmean(total_salaries)
# Out:
# np.float64(52802.5)

# %%
float(np.nanmean(total_salaries))
# Out:
# 52802.5

# %%
type(None)
# Out:
# NoneType

# %%
type(np.nan)
# Out:
# float

# %%
base_salaries_plus_ten = base_salaries + 10

# %%
base_salaries_plus_ten
# Out:
# array([40010., 35010., 58010., 39010.,    nan])

# %%
fourth_and_fifth_job_titles = job_titles[3:5]

# %%
fourth_and_fifth_job_titles
# Out:
# array(['Data Scientist', 'AI Engineer'], dtype='<U17')

# %%
jobs_with_more_than_point_one_bonus = job_titles[bonus_rates > .1]

# %%
jobs_with_more_than_point_one_bonus
# Out:
# array(['Data Analyst', 'Financial Analyst', 'Data Scientist'],
#       dtype='<U17')

# %%
 cumulative_sum_array = np.cumsum(base_salaries_plus_ten)

# %%
cumulative_sum_array
# Out:
# array([ 40010.,  75020., 133030., 172040.,     nan])

# %%
base_salary_std_dev = np.std(base_salaries)

# %%
base_salary_std_dev
# Out:
# np.float64(nan)

# %%
new_base_salary = base_salaries[:-1]

# %%
new_base_salary
# Out:
# array([40000., 35000., 58000., 39000.])

# %%
new_base_salary_std_dev = np.std(new_base_salary)

# %%
float(new_base_salary_std_dev)
# Out:
# 8860.022573334676
