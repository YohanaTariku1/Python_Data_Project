# %%
salary_list = [15500, 18000, 13000, 24000, 10000]

min(salary_list)
# Out:
# 10000

# %%
# total_salary_list = [calculate_raise(salary) for salary in salary_list]

# def calculate_raise(base_salary, bonus_rate=.1):
#     return base_salary + (base_salary * bonus_rate)

# lambda salary: salary * 1.1

total_salary_list = [(lambda salary: salary * 1.1)(salary) for salary in salary_list]

total_salary_list
# Out:
# [17050.0, 19800.0, 14300.000000000002, 26400.000000000004, 11000.0]

# %%
max(salary_list)
# Out:
# 24000

# %%
sum(salary_list)
# Out:
# 80500

# %%
sorted(salary_list)
# Out:
# [10000, 13000, 15500, 18000, 24000]

# %%
def calculate_salary(base_salary, bonus_rate, profit):
    return base_salary + (bonus_rate * profit)

# %%
calculate_salary(500, 0.04, 25000)
# Out:
# 1500.0

# %%
(lambda x: x* 2)(3)
# Out:
# 6

# %%
(lambda x, y: x * y)(3,4)
# Out:
# 12

# %%
mul_five = lambda x: x * 5

mul_five(30)
# Out:
# 150

# %%
total_salary = lambda base_salary, bonus_rate, profit: base_salary + (bonus_rate * profit)

# %%
total_salary(400, 0.1, 1000)
# Out:
# 500.0

# %%
job_data = [
    {
        "job_title": "Data Analyst",
        "skills": ["Python", "SQL", "Excel", "Tableau"],
        "remote": True
    },
    {
        "job_title": "Machine Learning Engineer",
        "skills": ["Python", "TensorFlow", "PyTorch", "Scikit-Learn"],
        "remote": False
    },
    {
        "job_title": "Data Scientist",
        "skills": ["Python", "R", "Statistics", "Machine Learning"],
        "remote": True
    },
    {
        "job_title": "Business Intelligence Analyst",
        "skills": ["SQL", "Power BI", "Excel", "Data Visualization"],
        "remote": False
    },
    {
        "job_title": "AI Researcher",
        "skills": ["Python", "Deep Learning", "Natural Language Processing", "PyTorch"],
        "remote": True
    }
]

# %%
print(job_data[0]['job_title'])
# Out:
# Data Analyst

# %%
print(job_data[2]['skills'])
# Out:
# ['Python', 'R', 'Statistics', 'Machine Learning']

# %% [markdown]
# **Filtering** **Data**

# %% [markdown]
# Filter jobs that have Python and are not remote

# %%
help(filter)
# Out:
# Help on class filter in module builtins:
#
# class filter(object)
#  |  filter(function or None, iterable) --> filter object
#  |
#  |  Return an iterator yielding those items of iterable for which function(item)
#  |  is true. If function is None, return the items that are true.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
list(filter(lambda job: 'Python' in job['skills'] and not job['remote'], job_data))
# Out:
# [{'job_title': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn'],
#   'remote': False}]
