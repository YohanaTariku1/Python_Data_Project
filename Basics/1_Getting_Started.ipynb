# %% [markdown]
# This is a normal text
#
# # Heading
#
# **bold**
#
# 1. Banana Bread
# 2. Fried rice with tuna
# 3. Fried rice with vegetable
#
# [More fasting food lists](https://migrationology.com/ethiopian-food-guide/)
