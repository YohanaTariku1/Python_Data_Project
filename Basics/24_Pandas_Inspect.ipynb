# %%
import pandas as pd

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %%
df.tail(10)
# Out:
#              job_title_short  \
# 785731         Data Engineer
# 785732         Data Engineer
# 785733     Software Engineer
# 785734      Business Analyst
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 785731                                      Data Engineer
# 785732                              Data Engineer (f/m/d)
# 785733                                    DevOps Engineer
# 785734                                  PreSales Engineer
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df['job_title_short'].head(10)
# Out:
# 0    Senior Data Engineer
# 1            Data Analyst
# 2           Data Engineer
# 3           Data Engineer
# 4           Data Engineer
# 5           Data Engineer
# 6    Senior Data Engineer
# 7           Data Engineer
# 8        Business Analyst
# 9          Data Scientist
# Name: job_title_short, dtype: object

# %%
len(df[df['job_work_from_home'] == True][['job_title_short', 'company_name']])
# Out:
# 69552

# %%
len(df)
# Out:
# 785741

# %%
785741 - 69552
# Out:
# 716189

# %%
df.iloc[50]
# Out:
# job_title_short                                  Machine Learning Engineer
# job_title                         Sr ML Engineer - Research & NLP (Remote)
# job_location                                           Toronto, ON, Canada
# job_via                                            via Careers At BenchSci
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Canada
# job_posted_date                                        2023-08-24 13:40:48
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                         Canada
# salary_rate                                                           None
# ...

# %%
df.iloc[50:61]
# Out:
#               job_title_short                                 job_title  \
# 50  Machine Learning Engineer  Sr ML Engineer - Research & NLP (Remote)
# 51       Senior Data Engineer                      Senior Data Engineer
# 52             Data Scientist     Data Scientist SME or Program Manager
# 53              Data Engineer                             Data Engineer
# 54              Data Engineer               Data and Analytics Engineer
# 55             Data Scientist                            Data Scientist
# 56      Senior Data Scientist           Principal Statistical Scientist
# 57              Data Engineer                             Data Engineer
# 58      Senior Data Scientist                     Senior Data Scientist
# 59              Data Engineer      Data Engineer with Dremio Experience
# 60           Business Analyst              Business Intelligence Intern
#
#                                   job_location                  job_via  \
# ...

# %%
df.iloc[50:61, 0:2]
# Out:
#               job_title_short                                 job_title
# 50  Machine Learning Engineer  Sr ML Engineer - Research & NLP (Remote)
# 51       Senior Data Engineer                      Senior Data Engineer
# 52             Data Scientist     Data Scientist SME or Program Manager
# 53              Data Engineer                             Data Engineer
# 54              Data Engineer               Data and Analytics Engineer
# 55             Data Scientist                            Data Scientist
# 56      Senior Data Scientist           Principal Statistical Scientist
# 57              Data Engineer                             Data Engineer
# 58      Senior Data Scientist                     Senior Data Scientist
# 59              Data Engineer      Data Engineer with Dremio Experience
# 60           Business Analyst              Business Intelligence Intern

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df[(df.job_work_from_home == True) & (df.salary_year_avg > 100000)]
# Out:
#               job_title_short  \
# 92              Data Engineer
# 116            Data Scientist
# 571             Data Engineer
# 773             Data Engineer
# 923             Data Engineer
# ...                       ...
# 779816  Senior Data Scientist
# 780443         Data Scientist
# 781466  Senior Data Scientist
# 782562   Senior Data Engineer
# 783761   Senior Data Engineer
#
#                                                 job_title job_location  \
# 92                Remote - Data Engineer - Permanent - W2     Anywhere
# 116                                        Data Scientist     Anywhere
# 571     Data Engineer ETL lnformatica API SQL Engineer...     Anywhere
# 773                               Principal Data Engineer     Anywhere
# 923                                     AWS Data Engineer     Anywhere
# ...                                                   ...          ...
# 779816                     Senior Data Scientist (Remote)     Anywhere
# ...

# %%
df[(df.job_work_from_home == True) & (df.salary_hour_avg).notna()]
# Out:
#              job_title_short  \
# 51      Senior Data Engineer
# 253            Data Engineer
# 397            Data Engineer
# 448           Data Scientist
# 499            Data Engineer
# ...                      ...
# 779886        Data Scientist
# 781307        Data Scientist
# 781499        Data Scientist
# 781796        Data Scientist
# 783976        Data Scientist
#
#                                                 job_title job_location  \
# 51                                   Senior Data Engineer     Anywhere
# 253                                         Data Engineer     Anywhere
# 397                                   Cloud Data Engineer     Anywhere
# 448     Jnr Data Scientist for exciting projects with ...     Anywhere
# 499                                         Data Engineer     Anywhere
# ...                                                   ...          ...
# 779886      Expert Data Analyst/Data Scientist Instructor     Anywhere
# ...
