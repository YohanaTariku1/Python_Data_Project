# %%
# import my_module

# %%
# my_module.skill_list

# %%
# my_module.skill("Python")

# %%
# import job_analyzer

# %%
# from job_analyzer import *

# %%
# calculate_salary(100000)

# calculate_bonus(110000, 100000)

# %%
# help(calculate_salary)

# %%
# help(calculate_bonus)

# %% [markdown]
# **Python Standard Library**

# %% [markdown]
# Statistics Module

# %%
import random

# %%
import statistics

# %%
salary_list = [120000, 310000, 260000, 100000, 95000]

# %%
from statistics import mean, median, mode

# %%
statistics.mean(salary_list)
# Out:
# 177000

# %%
random.random()
# Out:
# 0.12822066655741016

# %%
random.randint(1, 5)
# Out:
# 3

# %%
sample = random.sample(range(0, 50), 5)
print(sample)
# Out:
# [40, 5, 2, 32, 0]

# %%
random_num = list(range(0, 11))

# %%
random_nums = random.sample(random_num, 11)

# %%
print(random_nums)
# Out:
# [5, 0, 1, 2, 10, 6, 8, 7, 4, 3, 9]

# %%
num = list(range(0,6))
print(num)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
random_shuffle = random.shuffle(num)

# %%
print(num)
# Out:
# [5, 4, 2, 3, 1, 0]
