# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python','SQL','Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Data Analyst', 'job_skills': "['Excel','SQL','Tableau']", 'job_date': '2023-06-01'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python','TensorFlow','PyTorch']", 'job_date': '2023-07-14'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': "['Power BI','SQL','Data Visualization']", 'job_date': '2023-08-03'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python','Spark','Hadoop','SQL']", 'job_date': '2023-09-21'},
    {'job_title': 'AI Researcher', 'job_skills': "['Deep Learning','NLP','Python']", 'job_date': '2023-10-11'},
    {'job_title': 'Quantitative Analyst', 'job_skills': "['R','Python','Statistics']", 'job_date': '2023-11-05'},
    {'job_title': 'ETL Developer', 'job_skills': "['SQL','Informatica','Data Warehousing']", 'job_date': '2023-12-15'},
    {'job_title': 'Data Architect', 'job_skills': "['Cloud Computing','SQL','NoSQL']", 'job_date': '2024-01-20'},
    {'job_title': 'Computer Vision Engineer', 'job_skills': "['Python','OpenCV','Deep Learning']", 'job_date': '2024-02-17'}
]

# %% [markdown]
# ## **datetime**

# %%
from datetime import datetime, date
import ast

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 9, 29, 11, 8, 42, 105644)

# %%
data_science_jobs[0]
# Out:
# {'job_title': 'Data Scientist',
#  'job_skills': "['Python','SQL','Machine Learning']",
#  'job_date': '2023-05-12'}

# %%
type(data_science_jobs[0]['job_date'])
# Out:
# str

# %%
test_datetime = data_science_jobs[0]['job_date']

# %%
print(datetime.strptime(test_datetime, '%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
test_date = data_science_jobs[1]['job_date']

# %%
print(test_date)
# Out:
# 2023-06-01

# %%
type(test_date)
# Out:
# str

# %%
print(datetime.strptime(test_date, '%Y-%m-%d').date())
# Out:
# 2023-06-01

# %%
for job in data_science_jobs:
    job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
    job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['Excel', 'SQL', 'Tableau'],
#   'job_date': datetime.datetime(2023, 6, 1, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'PyTorch'],
#   'job_date': datetime.datetime(2023, 7, 14, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': ['Power BI', 'SQL', 'Data Visualization'],
#   'job_date': datetime.datetime(2023, 8, 3, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'Hadoop', 'SQL'],
#   'job_date': datetime.datetime(2023, 9, 21, 0, 0)},
#  {'job_title': 'AI Researcher',
#   'job_skills': ['Deep Learning', 'NLP', 'Python'],
#   'job_date': datetime.datetime(2023, 10, 11, 0, 0)},
#  {'job_title': 'Quantitative Analyst',
#   'job_skills': ['R', 'Python', 'Statistics'],
# ...
