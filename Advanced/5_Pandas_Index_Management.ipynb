# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#           job_title_short  ...                                    job_type_skills
# 269730   Business Analyst  ...  {'databases': ['sql server'], 'programming': [...
# 202587  Software Engineer  ...  {'cloud': ['snowflake'], 'libraries': ['spark'...
# 409161       Data Analyst  ...                                               None
# 210685     Data Scientist  ...                            {'programming': ['go']}
# 386199     Data Scientist  ...  {'libraries': ['pyspark', 'scikit-learn', 'ker...
#
# [5 rows x 17 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'job_index'

# %%
df.head(5)
# Out:
#                 job_title_short  ...                                    job_type_skills
# job_index                        ...
# 0          Senior Data Engineer  ...                                               None
# 1                  Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2                 Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3                 Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4                 Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
#
# [5 rows x 17 columns]

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa = df[df['job_country'] == 'United States']

df_usa.reset_index(inplace=True)

df_usa
# Out:
#         job_index  ...                                    job_type_skills
# 0               0  ...                                               None
# 1               3  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2               5  ...  {'cloud': ['gcp'], 'programming': ['python', '...
# 3               6  ...  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4               9  ...  {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...           ...  ...                                                ...
# 206287     785673  ...                                               None
# 206288     785685  ...  {'analyst_tools': ['excel'], 'programming': ['...
# 206289     785692  ...         {'programming': ['python', 'matlab', 'r']}
# 206290     785703  ...                                               None
# 206291     785705  ...  {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 18 columns]

# %%
df_usa
# Out:
#                 job_title_short  ...                                    job_type_skills
# job_index                        ...
# 0          Senior Data Engineer  ...                                               None
# 3                 Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5                 Data Engineer  ...  {'cloud': ['gcp'], 'programming': ['python', '...
# 6          Senior Data Engineer  ...  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9                Data Scientist  ...  {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                         ...  ...                                                ...
# 785673           Data Scientist  ...                                               None
# 785685             Data Analyst  ...  {'analyst_tools': ['excel'], 'programming': ['...
# 785692           Data Scientist  ...         {'programming': ['python', 'matlab', 'r']}
# 785703             Data Analyst  ...                                               None
# 785705             Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]

# %%
median_pivot = df_usa.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc=['median', 'max', 'min'])

# %%
median_pivot
# Out:
#                                    median             max             min
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0        387460.0         35000.0
# Cloud Engineer                   116100.0        221844.0         42000.0
# Data Analyst                      90000.0        375000.0         25000.0
# Data Engineer                    125000.0        525000.0         23496.0
# Data Scientist                   130000.0        960000.0         30000.0
# Machine Learning Engineer        150000.0        315000.0         44408.5
# Senior Data Analyst              110000.0        425000.0         35360.0
# Senior Data Engineer             150000.0        375000.0         45000.0
# Senior Data Scientist            155000.0        475000.0         55000.0
# Software Engineer                130000.0        375000.0         48982.0

# %%
median_pivot = median_pivot.sort_values(by=('median', 'salary_year_avg'), ascending=False)

median_pivot
# Out:
#                                    median             max             min
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155000.0        475000.0         55000.0
# Machine Learning Engineer        150000.0        315000.0         44408.5
# Senior Data Engineer             150000.0        375000.0         45000.0
# Data Scientist                   130000.0        960000.0         30000.0
# Software Engineer                130000.0        375000.0         48982.0
# Data Engineer                    125000.0        525000.0         23496.0
# Cloud Engineer                   116100.0        221844.0         42000.0
# Senior Data Analyst              110000.0        425000.0         35360.0
# Business Analyst                  90000.0        387460.0         35000.0
# Data Analyst                      90000.0        375000.0         25000.0

# %%
median_pivot.sort_index(inplace=True)

# %%
median_pivot
# Out:
#                                    median             max             min
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0        387460.0         35000.0
# Cloud Engineer                   116100.0        221844.0         42000.0
# Data Analyst                      90000.0        375000.0         25000.0
# Data Engineer                    125000.0        525000.0         23496.0
# Data Scientist                   130000.0        960000.0         30000.0
# Machine Learning Engineer        150000.0        315000.0         44408.5
# Senior Data Analyst              110000.0        425000.0         35360.0
# Senior Data Engineer             150000.0        375000.0         45000.0
# Senior Data Scientist            155000.0        475000.0         55000.0
# Software Engineer                130000.0        375000.0         48982.0
